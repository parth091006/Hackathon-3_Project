# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install streamlit==1.32.0
# Out:
# Collecting streamlit==1.32.0
#   Downloading streamlit-1.32.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit==1.32.0)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (8.3.1)
# Collecting numpy<2,>=1.19.3 (from streamlit==1.32.0)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting packaging<24,>=16.8 (from streamlit==1.32.0)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (2.2.3)
# Collecting pillow<11,>=7.1.0 (from streamlit==1.32.0)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting protobuf<5,>=3.20 (from streamlit==1.32.0)
#   Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (23.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from streamlit==1.32.0) (2.32.5)
# Collecting rich<14,>=10.14.0 (from streamlit==1.32.0)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit==1.32.0)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from streamlit==1.32.0) (6.5.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\parth\appdata\roaming\python\python312\site-packages (from streamlit==1.32.0) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from altair<6,>=4.0->streamlit==1.32.0) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from altair<6,>=4.0->streamlit==1.32.0) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\parth\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit==1.32.0) (2.16.0)
# Requirement already satisfied: colorama in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from click<9,>=7.0->streamlit==1.32.0) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.0) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\parth\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.0) (2025.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.0) (2026.1.4)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit==1.32.0)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.32.0) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.32.0) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.0) (0.30.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.32.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit==1.32.0) (1.17.0)
# Downloading streamlit-1.32.0-py2.py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 3.0 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.1 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 3.5 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 3.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.7 MB/s  0:00:03
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/731.2 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/731.2 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 731.2/731.2 kB 1.4 MB/s  0:00:00
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.6 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.1 MB/s  0:00:00
# Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: tenacity, protobuf, pillow, packaging, numpy, mdurl, markdown-it-py, rich, altair, streamlit
#
#   Attempting uninstall: tenacity
#
#     Found existing installation: tenacity 9.1.4
#
#     Uninstalling tenacity-9.1.4:
#
#       Successfully uninstalled tenacity-9.1.4
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 5.29.3
#
#    ---- -----------------------------------  1/10 [protobuf]
#     Uninstalling protobuf-5.29.3:
#    ---- -----------------------------------  1/10 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#    ---- -----------------------------------  1/10 [protobuf]
#   Attempting uninstall: pillow
#    ---- -----------------------------------  1/10 [protobuf]
#     Found existing installation: pillow 12.0.0
#    ---- -----------------------------------  1/10 [protobuf]
#    -------- -------------------------------  2/10 [pillow]
#     Uninstalling pillow-12.0.0:
#    -------- -------------------------------  2/10 [pillow]
#       Successfully uninstalled pillow-12.0.0
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#   Attempting uninstall: packaging
#    -------- -------------------------------  2/10 [pillow]
#     Found existing installation: packaging 25.0
#    -------- -------------------------------  2/10 [pillow]
#     Uninstalling packaging-25.0:
#    -------- -------------------------------  2/10 [pillow]
#       Successfully uninstalled packaging-25.0
#    -------- -------------------------------  2/10 [pillow]
#    ------------ ---------------------------  3/10 [packaging]
#   Attempting uninstall: numpy
#    ------------ ---------------------------  3/10 [packaging]
#     Found existing installation: numpy 2.2.6
#    ------------ ---------------------------  3/10 [packaging]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#     Uninstalling numpy-2.2.6:
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ------------------------ ---------------  6/10 [markdown-it-py]
#    ------------------------ ---------------  6/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [rich]
#    ---------------------------- -----------  7/10 [rich]
#   Attempting uninstall: altair
#    ---------------------------- -----------  7/10 [rich]
#     Found existing installation: altair 6.0.0
#    ---------------------------- -----------  7/10 [rich]
#    -------------------------------- -------  8/10 [altair]
#     Uninstalling altair-6.0.0:
#    -------------------------------- -------  8/10 [altair]
#       Successfully uninstalled altair-6.0.0
#    -------------------------------- -------  8/10 [altair]
#    -------------------------------- -------  8/10 [altair]
#    -------------------------------- -------  8/10 [altair]
#    -------------------------------- -------  8/10 [altair]
#    -------------------------------- -------  8/10 [altair]
#   Attempting uninstall: streamlit
#    -------------------------------- -------  8/10 [altair]
#     Found existing installation: streamlit 1.54.0
#    -------------------------------- -------  8/10 [altair]
#     Uninstalling streamlit-1.54.0:
#    -------------------------------- -------  8/10 [altair]
#    ------------------------------------ ---  9/10 [streamlit]
#    ------------------------------------ ---  9/10 [streamlit]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\google\~upb'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\~il'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\~-mpy'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\users\\parth\\appdata\\roaming\\python\\python312\\scripts\\streamlit.exe'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas==2.2.0
# Out:
# Collecting pandas==2.2.0
#   Downloading pandas-2.2.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from pandas==2.2.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from pandas==2.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parth\appdata\roaming\python\python312\site-packages (from pandas==2.2.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\parth\appdata\roaming\python\python312\site-packages (from pandas==2.2.0) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.0) (1.17.0)
# Downloading pandas-2.2.0-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.5 MB 5.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.5 MB 3.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.5 MB 3.4 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.5 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.5 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.5 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.5 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/11.5 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.5 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.5 MB 1.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 1.7 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.5 MB 1.8 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.5 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.3/11.5 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.8/11.5 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.5 MB 1.9 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.5 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.0/11.5 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 1.8 MB/s  0:00:06
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed pandas-2.2.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\PARTH\AppData\Roaming\Python\Python312\site-packages\~andas'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy==1.26.3
# Out:
# Collecting numpy==1.26.3
#   Downloading numpy-1.26.3-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Downloading numpy-1.26.3-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.5 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/15.5 MB 4.4 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/15.5 MB 3.8 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/15.5 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/15.5 MB 3.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/15.5 MB 3.4 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/15.5 MB 3.4 MB/s eta 0:00:04
#    ------------- -------------------------- 5.2/15.5 MB 3.1 MB/s eta 0:00:04
#    -------------- ------------------------- 5.5/15.5 MB 3.0 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.5 MB 2.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.6/15.5 MB 2.8 MB/s eta 0:00:04
#    ------------------ --------------------- 7.1/15.5 MB 2.8 MB/s eta 0:00:04
#    ------------------- -------------------- 7.6/15.5 MB 2.8 MB/s eta 0:00:03
#    -------------------- ------------------- 7.9/15.5 MB 2.7 MB/s eta 0:00:03
#    -------------------- ------------------- 8.1/15.5 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 8.1/15.5 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 8.4/15.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.5 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.9/15.5 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.2/15.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 9.7/15.5 MB 2.2 MB/s eta 0:00:03
#    -------------------------- ------------- 10.2/15.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 10.7/15.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.3/15.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.5 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 12.8/15.5 MB 2.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.4/15.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 2.4 MB/s  0:00:06
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.26.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install scikit-learn==1.4.0
# Out:
# Collecting scikit-learn==1.4.0
#   Downloading scikit_learn-1.4.0-1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from scikit-learn==1.4.0) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from scikit-learn==1.4.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from scikit-learn==1.4.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\parth\appdata\roaming\python\python312\site-packages (from scikit-learn==1.4.0) (3.6.0)
# Downloading scikit_learn-1.4.0-1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/10.6 MB 1.0 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/10.6 MB 1.1 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/10.6 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/10.6 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.8/10.6 MB 1.3 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/10.6 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/10.6 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.7/10.6 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.6 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.6 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.3/10.6 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.9/10.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 2.5 MB/s  0:00:04
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.2
#     Uninstalling scikit-learn-1.7.2:
#       Successfully uninstalled scikit-learn-1.7.2
# Successfully installed scikit-learn-1.4.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install joblib==1.3.2
# Out:
# Collecting joblib==1.3.2
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.2
#     Uninstalling joblib-1.5.2:
#       Successfully uninstalled joblib-1.5.2
# Successfully installed joblib-1.3.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install plotly==5.18.0
# Out:
# Collecting plotly==5.18.0
#   Downloading plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from plotly==5.18.0) (8.5.0)
# Requirement already satisfied: packaging in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from plotly==5.18.0) (23.2)
# Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.6 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/15.6 MB 3.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.1/15.6 MB 3.5 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/15.6 MB 3.5 MB/s eta 0:00:04
#    --------- ------------------------------ 3.7/15.6 MB 3.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.9/15.6 MB 3.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/15.6 MB 3.1 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/15.6 MB 2.8 MB/s eta 0:00:04
#    ------------ --------------------------- 5.0/15.6 MB 2.7 MB/s eta 0:00:04
#    -------------- ------------------------- 5.5/15.6 MB 2.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.6 MB 2.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.6/15.6 MB 2.6 MB/s eta 0:00:04
#    ------------------ --------------------- 7.1/15.6 MB 2.6 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/15.6 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 7.9/15.6 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/15.6 MB 2.4 MB/s eta 0:00:04
#    --------------------- ------------------ 8.4/15.6 MB 2.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.2/15.6 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 9.4/15.6 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.6 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 10.5/15.6 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.0/15.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.5/15.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 12.1/15.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 12.3/15.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.4/15.6 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 2.1 MB/s  0:00:07
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.5.2
#     Uninstalling plotly-6.5.2:
#       Successfully uninstalled plotly-6.5.2
# Successfully installed plotly-5.18.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install reportlab==4.0.9
# Out:
# Collecting reportlab==4.0.9
#   Downloading reportlab-4.0.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\parth\anaconda3\envs\myenv\lib\site-packages (from reportlab==4.0.9) (10.4.0)
# Collecting chardet (from reportlab==4.0.9)
#   Downloading chardet-6.0.0.post1-py3-none-any.whl.metadata (3.3 kB)
# Downloading reportlab-4.0.9-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/1.9 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.5 MB/s  0:00:00
# Downloading chardet-6.0.0.post1-py3-none-any.whl (627 kB)
#    ---------------------------------------- 0.0/627.2 kB ? eta -:--:--
#    ---------------------------------------- 627.2/627.2 kB 3.3 MB/s  0:00:00
# Installing collected packages: chardet, reportlab
#
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#    ---------------------------------------- 0/2 [chardet]
#   Attempting uninstall: reportlab
#    ---------------------------------------- 0/2 [chardet]
#     Found existing installation: reportlab 4.4.10
#    ---------------------------------------- 0/2 [chardet]
#     Uninstalling reportlab-4.4.10:
#    ---------------------------------------- 0/2 [chardet]
#    -------------------- ------------------- 1/2 [reportlab]
#       Successfully uninstalled reportlab-4.4.10
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    -------------------- ------------------- 1/2 [reportlab]
#    ---------------------------------------- 2/2 [reportlab]
#
# Successfully installed chardet-6.0.0.post1 reportlab-4.0.9
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
